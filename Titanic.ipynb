# %%
import numpy as np # linear algebra
import pandas as pd # data processing
from matplotlib import pyplot as plt

#update the train and test location
train = "train.csv"
test = "test.csv"

# %%
df_train = pd.read_csv(train)

# %%
# df_train.dtypes

# df_test[df_test['Pclass']==3]['Name']
x1='Age'
x2='Fare'
plt.plot(df_train[df_train['Survived']==1][x1],df_train[df_train['Survived']==1][x2],'g^',df_train[df_train['Survived']==0][x1],df_train[df_train['Survived']==0][x2],'r+',df_train[df_train['Survived']==1][x1],df_train[df_train['Survived']==1][x2],'g^')

# %%
x=[1,2,4]
y=[1,3,5]
z=[2,5,6]

plt.plot(x,z,y)
